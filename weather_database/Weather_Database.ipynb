# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 772

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | prince rupert
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 6 of Set 1 | haines junction
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | lompoc
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | mana
# Processing Record 13 of Set 1 | mandurah
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | batagay-alyta
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | champerico
# Processing Record 18 of Set 1 | kansanshi
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | dunedin
# Processing Record 21 of Set 1 | avera
# Processing Record 22 of Set 1 | sabang
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 24 of Set 1 | belvidere
# Processing Record 25 of Set 1 | amambai
# Processing Record 26 of Set 1 | omboue
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | sao miguel do oeste
# City not found. Skipping
# Processing Record 29 of Set 1 | lagoa
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | ughelli
# Processing Record 32 of Set 1 | ostrovnoy
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | sibolga
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | coruripe
# Processing Record 42 of Set 1 | fortuna
# Processing Record 43 of Set 1 | albanel
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | ialibu
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | whitehorse
# Processing Record 2 of Set 2 | camacha
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | miri
# Processing Record 6 of Set 2 | pangnirtung
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | ilulissat
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | harper
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | formoso do araguaia
# City not found. Skipping
# Processing Record 14 of Set 2 | afua
# Processing Record 15 of Set 2 | marcona
# City not found. Skipping
# Processing Record 16 of Set 2 | krasnoselkup
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | marystown
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | ayan
# Processing Record 24 of Set 2 | lodwar
# Processing Record 25 of Set 2 | sambava
# Processing Record 26 of Set 2 | kraskino
# Processing Record 27 of Set 2 | zyryanka
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | zabol
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | monte escobedo
# Processing Record 32 of Set 2 | yangjiang
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | grand gaube
# Processing Record 35 of Set 2 | sorong
# Processing Record 36 of Set 2 | anadyr
# Processing Record 37 of Set 2 | margate
# Processing Record 38 of Set 2 | qujing
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | faanui
# Processing Record 42 of Set 2 | phan rang
# City not found. Skipping
# Processing Record 43 of Set 2 | lingao
# Processing Record 44 of Set 2 | honningsvag
# Processing Record 45 of Set 2 | touros
# Processing Record 46 of Set 2 | lolua
# City not found. Skipping
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | labuhan
# Processing Record 50 of Set 2 | chapais
# Processing Record 1 of Set 3 | eureka
# Processing Record 2 of Set 3 | pavelets
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | cananea
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | sheridan
# Processing Record 7 of Set 3 | tezu
# Processing Record 8 of Set 3 | provideniya
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | barlinek
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | akhisar
# Processing Record 16 of Set 3 | pemberton
# Processing Record 17 of Set 3 | lukovetskiy
# Processing Record 18 of Set 3 | san antero
# Processing Record 19 of Set 3 | cottonwood
# Processing Record 20 of Set 3 | dzhusaly
# City not found. Skipping
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping
# Processing Record 22 of Set 3 | bowen
# Processing Record 23 of Set 3 | north battleford
# Processing Record 24 of Set 3 | valparaiso
# Processing Record 25 of Set 3 | itarema
# Processing Record 26 of Set 3 | galle
# Processing Record 27 of Set 3 | konstantinovka
# Processing Record 28 of Set 3 | filingue
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping
# Processing Record 30 of Set 3 | namatanai
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | burnie
# Processing Record 33 of Set 3 | domoni
# Processing Record 34 of Set 3 | ballina
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | imeni poliny osipenko
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | shetpe
# Processing Record 39 of Set 3 | maumere
# Processing Record 40 of Set 3 | nadym
# Processing Record 41 of Set 3 | talnakh
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | orebro
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | san andres
# Processing Record 48 of Set 3 | evensk
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | dien bien
# City not found. Skipping
# Processing Record 1 of Set 4 | tagusao
# Processing Record 2 of Set 4 | hervey bay
# Processing Record 3 of Set 4 | yarmouth
# Processing Record 4 of Set 4 | douentza
# Processing Record 5 of Set 4 | bergama
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | menongue
# Processing Record 8 of Set 4 | norman wells
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | necochea
# Processing Record 11 of Set 4 | ngunguru
# Processing Record 12 of Set 4 | napasar
# Processing Record 13 of Set 4 | mosetse
# Processing Record 14 of Set 4 | taonan
# Processing Record 15 of Set 4 | maceio
# Processing Record 16 of Set 4 | ossora
# Processing Record 17 of Set 4 | mar del plata
# Processing Record 18 of Set 4 | vondrozo
# Processing Record 19 of Set 4 | bethel
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | surgut
# Processing Record 22 of Set 4 | chauk
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | port macquarie
# Processing Record 25 of Set 4 | mannargudi
# Processing Record 26 of Set 4 | maloy
# Processing Record 27 of Set 4 | hobart
# Processing Record 28 of Set 4 | bur gabo
# City not found. Skipping
# Processing Record 29 of Set 4 | datong
# Processing Record 30 of Set 4 | ulladulla
# Processing Record 31 of Set 4 | svetlogorsk
# Processing Record 32 of Set 4 | komyshuvakha
# Processing Record 33 of Set 4 | hami
# Processing Record 34 of Set 4 | salinas
# Processing Record 35 of Set 4 | tutoia
# Processing Record 36 of Set 4 | biak
# Processing Record 37 of Set 4 | balaipungut
# Processing Record 38 of Set 4 | isilkul
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping
# Processing Record 40 of Set 4 | vaitape
# Processing Record 41 of Set 4 | yaitepec
# City not found. Skipping
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | hambantota
# Processing Record 44 of Set 4 | hushitai
# Processing Record 45 of Set 4 | kuche
# City not found. Skipping
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping
# Processing Record 47 of Set 4 | namibe
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | wilmington
# Processing Record 50 of Set 4 | colon
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | hemsedal
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | batsfjord
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | dongsheng
# Processing Record 8 of Set 5 | moen
# Processing Record 9 of Set 5 | bluff
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | asau
# Processing Record 14 of Set 5 | zhangye
# Processing Record 15 of Set 5 | zhanaozen
# Processing Record 16 of Set 5 | cap malheureux
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | barranca
# Processing Record 19 of Set 5 | marrakesh
# Processing Record 20 of Set 5 | atbasar
# Processing Record 21 of Set 5 | ambilobe
# Processing Record 22 of Set 5 | guerrero negro
# Processing Record 23 of Set 5 | catio
# Processing Record 24 of Set 5 | sao felix do xingu
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | fukuma
# Processing Record 27 of Set 5 | henties bay
# Processing Record 28 of Set 5 | havoysund
# Processing Record 29 of Set 5 | rungata
# City not found. Skipping
# Processing Record 30 of Set 5 | kirakira
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | nishihara
# Processing Record 34 of Set 5 | paamiut
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | corrientes
# Processing Record 37 of Set 5 | korla
# Processing Record 38 of Set 5 | carsamba
# Processing Record 39 of Set 5 | vardo
# Processing Record 40 of Set 5 | mstera
# Processing Record 41 of Set 5 | lensk
# Processing Record 42 of Set 5 | pisco
# Processing Record 43 of Set 5 | kabinda
# Processing Record 44 of Set 5 | sao jose da coroa grande
# Processing Record 45 of Set 5 | trudovoye
# Processing Record 46 of Set 5 | lichinga
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | belaya gora
# Processing Record 49 of Set 5 | alegrete
# Processing Record 50 of Set 5 | alice town
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | cidreira
# Processing Record 3 of Set 6 | baykit
# Processing Record 4 of Set 6 | banda aceh
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | khovu-aksy
# Processing Record 7 of Set 6 | abilene
# Processing Record 8 of Set 6 | viedma
# Processing Record 9 of Set 6 | havelock
# Processing Record 10 of Set 6 | winnemucca
# Processing Record 11 of Set 6 | ngukurr
# City not found. Skipping
# Processing Record 12 of Set 6 | artyom
# Processing Record 13 of Set 6 | payo
# Processing Record 14 of Set 6 | foca
# Processing Record 15 of Set 6 | hasaki
# Processing Record 16 of Set 6 | gubkinskiy
# Processing Record 17 of Set 6 | horodyshche
# Processing Record 18 of Set 6 | kasongo-lunda
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | kendari
# Processing Record 22 of Set 6 | eyl
# Processing Record 23 of Set 6 | upernavik
# Processing Record 24 of Set 6 | kununurra
# Processing Record 25 of Set 6 | rusape
# Processing Record 26 of Set 6 | mullaitivu
# City not found. Skipping
# Processing Record 27 of Set 6 | sinazongwe
# Processing Record 28 of Set 6 | tuatapere
# Processing Record 29 of Set 6 | wanning
# Processing Record 30 of Set 6 | waipawa
# Processing Record 31 of Set 6 | ranong
# Processing Record 32 of Set 6 | sai buri
# Processing Record 33 of Set 6 | changqing
# Processing Record 34 of Set 6 | bosaso
# Processing Record 35 of Set 6 | bubaque
# Processing Record 36 of Set 6 | iralaya
# Processing Record 37 of Set 6 | concordia
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | oranjemund
# Processing Record 40 of Set 6 | pedraza
# Processing Record 41 of Set 6 | saskylakh
# Processing Record 42 of Set 6 | port moresby
# Processing Record 43 of Set 6 | toora-khem
# Processing Record 44 of Set 6 | vestmannaeyjar
# Processing Record 45 of Set 6 | sarankhola
# Processing Record 46 of Set 6 | vuktyl
# Processing Record 47 of Set 6 | kavaratti
# Processing Record 48 of Set 6 | coihaique
# Processing Record 49 of Set 6 | vanimo
# Processing Record 50 of Set 6 | rio negrinho
# Processing Record 1 of Set 7 | tilichiki
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | ban nahin
# Processing Record 4 of Set 7 | husum
# Processing Record 5 of Set 7 | salalah
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | araouane
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping
# Processing Record 10 of Set 7 | brae
# Processing Record 11 of Set 7 | roald
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | chokwe
# Processing Record 14 of Set 7 | lamu
# Processing Record 15 of Set 7 | khani
# Processing Record 16 of Set 7 | la asuncion
# Processing Record 17 of Set 7 | arlit
# Processing Record 18 of Set 7 | sentyabrskiy
# City not found. Skipping
# Processing Record 19 of Set 7 | aklavik
# Processing Record 20 of Set 7 | sulphur springs
# Processing Record 21 of Set 7 | deputatskiy
# Processing Record 22 of Set 7 | grindavik
# Processing Record 23 of Set 7 | kaitangata
# Processing Record 24 of Set 7 | osmena
# Processing Record 25 of Set 7 | gimli
# Processing Record 26 of Set 7 | linshu
# City not found. Skipping
# Processing Record 27 of Set 7 | ulaanbaatar
# Processing Record 28 of Set 7 | camacupa
# Processing Record 29 of Set 7 | chama
# Processing Record 30 of Set 7 | revuca
# Processing Record 31 of Set 7 | port antonio
# Processing Record 32 of Set 7 | lutkun
# Processing Record 33 of Set 7 | tobermory
# Processing Record 34 of Set 7 | yellowknife
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | havre-saint-pierre
# Processing Record 37 of Set 7 | vila
# Processing Record 38 of Set 7 | artyk
# City not found. Skipping
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | praia da vitoria
# Processing Record 41 of Set 7 | erdenet
# Processing Record 42 of Set 7 | kunya
# Processing Record 43 of Set 7 | camocim
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | clyde river
# Processing Record 46 of Set 7 | yarada
# Processing Record 47 of Set 7 | sheregesh
# Processing Record 48 of Set 7 | marolambo
# Processing Record 49 of Set 7 | teacapan
# Processing Record 50 of Set 7 | dahuk
# Processing Record 1 of Set 8 | kenora
# Processing Record 2 of Set 8 | okha
# Processing Record 3 of Set 8 | coquimbo
# Processing Record 4 of Set 8 | ponta delgada
# Processing Record 5 of Set 8 | tubruq
# City not found. Skipping
# Processing Record 6 of Set 8 | fort wellington
# Processing Record 7 of Set 8 | agadir
# Processing Record 8 of Set 8 | lasa
# Processing Record 9 of Set 8 | ust-karsk
# Processing Record 10 of Set 8 | cabo san lucas
# Processing Record 11 of Set 8 | jalingo
# Processing Record 12 of Set 8 | barsovo
# Processing Record 13 of Set 8 | abu kamal
# Processing Record 14 of Set 8 | canutama
# Processing Record 15 of Set 8 | maiduguri
# Processing Record 16 of Set 8 | sao bento do sul
# Processing Record 17 of Set 8 | fairbanks
# Processing Record 18 of Set 8 | staraya poltavka
# Processing Record 19 of Set 8 | tarudant
# City not found. Skipping
# Processing Record 20 of Set 8 | atambua
# Processing Record 21 of Set 8 | saleaula
# City not found. Skipping
# Processing Record 22 of Set 8 | arica
# Processing Record 23 of Set 8 | kaya
# Processing Record 24 of Set 8 | florida
# Processing Record 25 of Set 8 | thinadhoo
# Processing Record 26 of Set 8 | ararat
# Processing Record 27 of Set 8 | bonthe
# Processing Record 28 of Set 8 | abha
# Processing Record 29 of Set 8 | kysyl-syr
# Processing Record 30 of Set 8 | west bay
# Processing Record 31 of Set 8 | acajutla
# Processing Record 32 of Set 8 | bonavista
# Processing Record 33 of Set 8 | gamba
# Processing Record 34 of Set 8 | marsh harbour
# Processing Record 35 of Set 8 | buchanan
# Processing Record 36 of Set 8 | sioux lookout
# Processing Record 37 of Set 8 | beira
# Processing Record 38 of Set 8 | yangambi
# Processing Record 39 of Set 8 | shelbyville
# Processing Record 40 of Set 8 | umzimvubu
# City not found. Skipping
# Processing Record 41 of Set 8 | maine-soroa
# Processing Record 42 of Set 8 | den helder
# Processing Record 43 of Set 8 | dovbysh
# Processing Record 44 of Set 8 | veraval
# Processing Record 45 of Set 8 | ola
# Processing Record 46 of Set 8 | ambatondrazaka
# Processing Record 47 of Set 8 | latung
# Processing Record 48 of Set 8 | trincomalee
# Processing Record 49 of Set 8 | babanusah
# City not found. Skipping
# Processing Record 50 of Set 8 | vao
# Processing Record 1 of Set 9 | bredy
# Processing Record 2 of Set 9 | kieta
# Processing Record 3 of Set 9 | boende
# Processing Record 4 of Set 9 | atar
# Processing Record 5 of Set 9 | ust-nera
# Processing Record 6 of Set 9 | lagunas
# Processing Record 7 of Set 9 | yulara
# Processing Record 8 of Set 9 | bengkulu
# Processing Record 9 of Set 9 | port lincoln
# Processing Record 10 of Set 9 | umm lajj
# Processing Record 11 of Set 9 | ilheus
# Processing Record 12 of Set 9 | pacific grove
# Processing Record 13 of Set 9 | elko
# Processing Record 14 of Set 9 | goulburn
# Processing Record 15 of Set 9 | palabuhanratu
# City not found. Skipping
# Processing Record 16 of Set 9 | altay
# Processing Record 17 of Set 9 | mehamn
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | olafsvik
# Processing Record 20 of Set 9 | san miguel de cauri
# Processing Record 21 of Set 9 | tasbuget
# City not found. Skipping
# Processing Record 22 of Set 9 | nowe miasto lubawskie
# Processing Record 23 of Set 9 | burica
# City not found. Skipping
# Processing Record 24 of Set 9 | shchelyayur
# City not found. Skipping
# Processing Record 25 of Set 9 | purpe
# Processing Record 26 of Set 9 | tura
# Processing Record 27 of Set 9 | alta floresta
# Processing Record 28 of Set 9 | gatton
# Processing Record 29 of Set 9 | bardiyah
# Processing Record 30 of Set 9 | westport
# Processing Record 31 of Set 9 | los lunas
# Processing Record 32 of Set 9 | hovd
# Processing Record 33 of Set 9 | ivolginsk
# Processing Record 34 of Set 9 | salinopolis
# Processing Record 35 of Set 9 | naifaru
# Processing Record 36 of Set 9 | constitucion
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | bagdarin
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | louisbourg
# City not found. Skipping
# Processing Record 42 of Set 9 | almenara
# Processing Record 43 of Set 9 | lavrentiya
# Processing Record 44 of Set 9 | diffa
# Processing Record 45 of Set 9 | codrington
# Processing Record 46 of Set 9 | vichayal
# City not found. Skipping
# Processing Record 47 of Set 9 | beloha
# Processing Record 48 of Set 9 | gongzhuling
# Processing Record 49 of Set 9 | souillac
# Processing Record 50 of Set 9 | aleppo
# Processing Record 1 of Set 10 | portland
# Processing Record 2 of Set 10 | cururupu
# Processing Record 3 of Set 10 | minab
# Processing Record 4 of Set 10 | dakar
# Processing Record 5 of Set 10 | gobabis
# Processing Record 6 of Set 10 | vestmanna
# Processing Record 7 of Set 10 | mentok
# City not found. Skipping
# Processing Record 8 of Set 10 | revelstoke
# Processing Record 9 of Set 10 | xichang
# Processing Record 10 of Set 10 | san bartolome de tirajana
# Processing Record 11 of Set 10 | fare
# Processing Record 12 of Set 10 | vanderhoof
# Processing Record 13 of Set 10 | simbahan
# Processing Record 14 of Set 10 | koumac
# Processing Record 15 of Set 10 | goundam
# Processing Record 16 of Set 10 | trinidad
# Processing Record 17 of Set 10 | jardim
# Processing Record 18 of Set 10 | iracoubo
# Processing Record 19 of Set 10 | pecos
# Processing Record 20 of Set 10 | perustica
# City not found. Skipping
# Processing Record 21 of Set 10 | solone
# Processing Record 22 of Set 10 | sorvag
# City not found. Skipping
# Processing Record 23 of Set 10 | clarence town
# Processing Record 24 of Set 10 | nago
# Processing Record 25 of Set 10 | moron
# Processing Record 26 of Set 10 | chihuahua
# Processing Record 27 of Set 10 | gwanda
# Processing Record 28 of Set 10 | colac
# Processing Record 29 of Set 10 | umm ruwabah
# City not found. Skipping
# Processing Record 30 of Set 10 | fort frances
# Processing Record 31 of Set 10 | union
# Processing Record 32 of Set 10 | darnah
# Processing Record 33 of Set 10 | tazovskiy
# Processing Record 34 of Set 10 | karaul
# City not found. Skipping
# Processing Record 35 of Set 10 | fevralsk
# City not found. Skipping
# Processing Record 36 of Set 10 | port hedland
# Processing Record 37 of Set 10 | mys shmidta
# City not found. Skipping
# Processing Record 38 of Set 10 | tommot
# Processing Record 39 of Set 10 | bireun
# Processing Record 40 of Set 10 | puerto del rosario
# Processing Record 41 of Set 10 | xingcheng
# Processing Record 42 of Set 10 | bargal
# City not found. Skipping
# Processing Record 43 of Set 10 | fuerte
# Processing Record 44 of Set 10 | tautira
# Processing Record 45 of Set 10 | chagda
# City not found. Skipping
# Processing Record 46 of Set 10 | siddipet
# Processing Record 47 of Set 10 | swift current
# Processing Record 48 of Set 10 | ostersund
# Processing Record 49 of Set 10 | sistranda
# Processing Record 50 of Set 10 | nouadhibou
# Processing Record 1 of Set 11 | saint george
# Processing Record 2 of Set 11 | florianopolis
# Processing Record 3 of Set 11 | sayhat
# Processing Record 4 of Set 11 | yunjinghong
# City not found. Skipping
# Processing Record 5 of Set 11 | ambodifototra
# City not found. Skipping
# Processing Record 6 of Set 11 | elkhart
# Processing Record 7 of Set 11 | samarai
# Processing Record 8 of Set 11 | palu
# Processing Record 9 of Set 11 | jambi
# Processing Record 10 of Set 11 | takoradi
# Processing Record 11 of Set 11 | lyubeshiv
# City not found. Skipping
# Processing Record 12 of Set 11 | vostok
# Processing Record 13 of Set 11 | nabire
# Processing Record 14 of Set 11 | komsomolskiy
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | kungurtug
# Processing Record 17 of Set 11 | marsa matruh
# Processing Record 18 of Set 11 | krasnyy chikoy
# Processing Record 19 of Set 11 | springfield
# Processing Record 20 of Set 11 | galesong
# Processing Record 21 of Set 11 | barry
# Processing Record 22 of Set 11 | suluq
# Processing Record 23 of Set 11 | lata
# Processing Record 24 of Set 11 | nantucket
# Processing Record 25 of Set 11 | benguela
# Processing Record 26 of Set 11 | nanchang
# Processing Record 27 of Set 11 | enshi
# Processing Record 28 of Set 11 | nioro
# Processing Record 29 of Set 11 | qarqin
# Processing Record 30 of Set 11 | pithapuram
# Processing Record 31 of Set 11 | bani
# Processing Record 32 of Set 11 | cabedelo
# Processing Record 33 of Set 11 | aykhal
# Processing Record 34 of Set 11 | dalbandin
# Processing Record 35 of Set 11 | gisborne
# Processing Record 36 of Set 11 | nouakchott
# Processing Record 37 of Set 11 | stillwater
# Processing Record 38 of Set 11 | bathsheba
# Processing Record 39 of Set 11 | olinda
# Processing Record 40 of Set 11 | jutai
# Processing Record 41 of Set 11 | bandundu
# Processing Record 42 of Set 11 | port-cartier
# Processing Record 43 of Set 11 | camapua
# Processing Record 44 of Set 11 | ancud
# Processing Record 45 of Set 11 | los llanos de aridane
# Processing Record 46 of Set 11 | faya
# Processing Record 47 of Set 11 | gat
# Processing Record 48 of Set 11 | ozgon
# City not found. Skipping
# Processing Record 49 of Set 11 | qasigiannguit
# Processing Record 50 of Set 11 | dargaville
# Processing Record 1 of Set 12 | esperance
# Processing Record 2 of Set 12 | aswan
# Processing Record 3 of Set 12 | jiuquan
# Processing Record 4 of Set 12 | san antonio
# Processing Record 5 of Set 12 | riviere-au-renard
# Processing Record 6 of Set 12 | katherine
# Processing Record 7 of Set 12 | antonovo
# Processing Record 8 of Set 12 | grand river south east
# City not found. Skipping
# Processing Record 9 of Set 12 | torbat-e jam
# Processing Record 10 of Set 12 | gari
# Processing Record 11 of Set 12 | shatrovo
# Processing Record 12 of Set 12 | changli
# Processing Record 13 of Set 12 | awbari
# Processing Record 14 of Set 12 | rottingdean
# Processing Record 15 of Set 12 | sechura
# Processing Record 16 of Set 12 | eskisehir
# Processing Record 17 of Set 12 | sorland
# Processing Record 18 of Set 12 | ternate
# Processing Record 19 of Set 12 | shimoda
# Processing Record 20 of Set 12 | gurkovo
# Processing Record 21 of Set 12 | saint-francois
# Processing Record 22 of Set 12 | rocha
# Processing Record 23 of Set 12 | ishigaki
# Processing Record 24 of Set 12 | ust-tsilma
# Processing Record 25 of Set 12 | dryden
# Processing Record 26 of Set 12 | nyimba
# Processing Record 27 of Set 12 | saint anthony
# Processing Record 28 of Set 12 | jacqueville
# Processing Record 29 of Set 12 | salina cruz
# Processing Record 30 of Set 12 | pustoshka
# Processing Record 31 of Set 12 | oyama
# Processing Record 32 of Set 12 | zverinogolovskoye
# Processing Record 33 of Set 12 | ayagoz
# Processing Record 34 of Set 12 | ponnani
# Processing Record 35 of Set 12 | griffith
# Processing Record 36 of Set 12 | pundaguitan
# Processing Record 37 of Set 12 | shellbrook
# Processing Record 38 of Set 12 | tabou
# Processing Record 39 of Set 12 | manaus
# Processing Record 40 of Set 12 | coahuayana
# Processing Record 41 of Set 12 | sawakin
# Processing Record 42 of Set 12 | klaeng
# Processing Record 43 of Set 12 | smithers
# Processing Record 44 of Set 12 | irbit
# Processing Record 45 of Set 12 | hillsborough
# Processing Record 46 of Set 12 | lanxi
# Processing Record 47 of Set 12 | geraldton
# Processing Record 48 of Set 12 | puerto madero
# Processing Record 49 of Set 12 | buala
# Processing Record 50 of Set 12 | cedar city
# Processing Record 1 of Set 13 | jamnah
# City not found. Skipping
# Processing Record 2 of Set 13 | katete
# Processing Record 3 of Set 13 | mitsamiouli
# Processing Record 4 of Set 13 | hede
# Processing Record 5 of Set 13 | shiraz
# Processing Record 6 of Set 13 | mirpur sakro
# Processing Record 7 of Set 13 | dhidhdhoo
# Processing Record 8 of Set 13 | robertsport
# Processing Record 9 of Set 13 | caraquet
# Processing Record 10 of Set 13 | yinchuan
# Processing Record 11 of Set 13 | salekhard
# Processing Record 12 of Set 13 | havre
# Processing Record 13 of Set 13 | iskateley
# Processing Record 14 of Set 13 | ardistan
# City not found. Skipping
# Processing Record 15 of Set 13 | berlevag
# Processing Record 16 of Set 13 | pont casse
# City not found. Skipping
# Processing Record 17 of Set 13 | izumo
# Processing Record 18 of Set 13 | xaltianguis
# Processing Record 19 of Set 13 | tambul
# City not found. Skipping
# Processing Record 20 of Set 13 | grimstad
# Processing Record 21 of Set 13 | lang son
# Processing Record 22 of Set 13 | businga
# Processing Record 23 of Set 13 | sayat
# Processing Record 24 of Set 13 | kilrush
# Processing Record 25 of Set 13 | grand bend
# Processing Record 26 of Set 13 | garowe
# Processing Record 27 of Set 13 | port-gentil
# Processing Record 28 of Set 13 | asilah
# Processing Record 29 of Set 13 | isabela
# Processing Record 30 of Set 13 | mahajanga
# Processing Record 31 of Set 13 | osinniki
# Processing Record 32 of Set 13 | shar
# Processing Record 33 of Set 13 | longkou
# Processing Record 34 of Set 13 | xining
# Processing Record 35 of Set 13 | naze
# Processing Record 36 of Set 13 | carlsbad
# Processing Record 37 of Set 13 | borba
# Processing Record 38 of Set 13 | kayerkan
# Processing Record 39 of Set 13 | kapuskasing
# Processing Record 40 of Set 13 | shingu
# Processing Record 41 of Set 13 | lucapa
# Processing Record 42 of Set 13 | kabansk
# Processing Record 43 of Set 13 | chitungwiza
# Processing Record 44 of Set 13 | seydi
# Processing Record 45 of Set 13 | alugan
# Processing Record 46 of Set 13 | xingyi
# Processing Record 47 of Set 13 | santa cruz
# Processing Record 48 of Set 13 | honiara
# Processing Record 49 of Set 13 | pemangkat
# Processing Record 50 of Set 13 | talara
# Processing Record 1 of Set 14 | tabiauea
# City not found. Skipping
# Processing Record 2 of Set 14 | nara
# Processing Record 3 of Set 14 | alto araguaia
# Processing Record 4 of Set 14 | rovaniemi
# Processing Record 5 of Set 14 | hualmay
# Processing Record 6 of Set 14 | eirunepe
# Processing Record 7 of Set 14 | mareeba
# Processing Record 8 of Set 14 | tynda
# Processing Record 9 of Set 14 | qaqortoq
# Processing Record 10 of Set 14 | tumannyy
# City not found. Skipping
# Processing Record 11 of Set 14 | vaida
# Processing Record 12 of Set 14 | tarko-sale
# Processing Record 13 of Set 14 | padang
# Processing Record 14 of Set 14 | samana
# Processing Record 15 of Set 14 | poum
# Processing Record 16 of Set 14 | nichinan
# Processing Record 17 of Set 14 | jalu
# Processing Record 18 of Set 14 | bereda
# Processing Record 19 of Set 14 | halol
# Processing Record 20 of Set 14 | yar-sale
# Processing Record 21 of Set 14 | lillesand
# Processing Record 22 of Set 14 | saint-joseph
# Processing Record 23 of Set 14 | marzuq
# Processing Record 24 of Set 14 | santa isabel do rio negro
# Processing Record 25 of Set 14 | ust-kuyga
# Processing Record 26 of Set 14 | broome
# Processing Record 27 of Set 14 | cayenne
# Processing Record 28 of Set 14 | nyrob
# Processing Record 29 of Set 14 | peniche
# Processing Record 30 of Set 14 | singaraja
# Processing Record 31 of Set 14 | jalakandapuram
# Processing Record 32 of Set 14 | barra do garcas
# Processing Record 33 of Set 14 | glubokiy
# Processing Record 34 of Set 14 | fort nelson
# Processing Record 35 of Set 14 | umm kaddadah
# Processing Record 36 of Set 14 | mocambique
# City not found. Skipping
# Processing Record 37 of Set 14 | nouna
# Processing Record 38 of Set 14 | marathon
# Processing Record 39 of Set 14 | meulaboh
# Processing Record 40 of Set 14 | sakakah
# Processing Record 41 of Set 14 | bartica
# Processing Record 42 of Set 14 | hay river
# Processing Record 43 of Set 14 | amahai
# Processing Record 44 of Set 14 | bodden town
# Processing Record 45 of Set 14 | san jeronimo
# Processing Record 46 of Set 14 | antsohihy
# Processing Record 47 of Set 14 | ritchie
# Processing Record 48 of Set 14 | nogales
# Processing Record 49 of Set 14 | luwuk
# Processing Record 50 of Set 14 | matara
# Processing Record 1 of Set 15 | seymchan
# Processing Record 2 of Set 15 | iquique
# Processing Record 3 of Set 15 | muros
# Processing Record 4 of Set 15 | emba
# Processing Record 5 of Set 15 | itoman
# Processing Record 6 of Set 15 | mwinilunga
# Processing Record 7 of Set 15 | rennes
# Processing Record 8 of Set 15 | maraa
# Processing Record 9 of Set 15 | dano
# Processing Record 10 of Set 15 | santa luzia
# Processing Record 11 of Set 15 | arrecife
# Processing Record 12 of Set 15 | hit
# Processing Record 13 of Set 15 | yeppoon
# Processing Record 14 of Set 15 | san quintin
# Processing Record 15 of Set 15 | fukue
# Processing Record 16 of Set 15 | darhan
# Processing Record 17 of Set 15 | egvekinot
# Processing Record 18 of Set 15 | the pas
# Processing Record 19 of Set 15 | riyadh
# Processing Record 20 of Set 15 | chopda
# Processing Record 21 of Set 15 | bandarbeyla
# Processing Record 22 of Set 15 | juruti
# Processing Record 23 of Set 15 | siavonga
# Processing Record 24 of Set 15 | dolzhanskaya
# Processing Record 25 of Set 15 | ugoofaaru
# Processing Record 26 of Set 15 | skjervoy
# Processing Record 27 of Set 15 | inirida
# Processing Record 28 of Set 15 | college
# Processing Record 29 of Set 15 | puerto el triunfo
# Processing Record 30 of Set 15 | duluth
# Processing Record 31 of Set 15 | almaznyy
# Processing Record 32 of Set 15 | mugur-aksy
# Processing Record 33 of Set 15 | emmett
# Processing Record 34 of Set 15 | warri
# Processing Record 35 of Set 15 | saulkrasti
# Processing Record 36 of Set 15 | sakaiminato
# Processing Record 37 of Set 15 | yumen
# Processing Record 38 of Set 15 | chiredzi
# Processing Record 39 of Set 15 | barentu
# Processing Record 40 of Set 15 | kajaani
# Processing Record 41 of Set 15 | arys
# Processing Record 42 of Set 15 | karratha
# Processing Record 43 of Set 15 | rach gia
# Processing Record 44 of Set 15 | mariinsk
# Processing Record 45 of Set 15 | la ronge
# Processing Record 46 of Set 15 | bhatgaon
# Processing Record 47 of Set 15 | okhotsk
# Processing Record 48 of Set 15 | bargi
# Processing Record 49 of Set 15 | la paz
# Processing Record 50 of Set 15 | pingliang
# Processing Record 1 of Set 16 | tual
# Processing Record 2 of Set 16 | teya
# Processing Record 3 of Set 16 | sumbe
# Processing Record 4 of Set 16 | mawlaik
# Processing Record 5 of Set 16 | el wasta
# City not found. Skipping
# Processing Record 6 of Set 16 | dhenkanal
# Processing Record 7 of Set 16 | manavalakurichi
# Processing Record 8 of Set 16 | salihorsk
# Processing Record 9 of Set 16 | nongstoin
# Processing Record 10 of Set 16 | balakhninskiy
# Processing Record 11 of Set 16 | sinnamary
# Processing Record 12 of Set 16 | aksu
# Processing Record 13 of Set 16 | muzhi
# Processing Record 14 of Set 16 | sapozhok
# Processing Record 15 of Set 16 | linchuan
# City not found. Skipping
# Processing Record 16 of Set 16 | moulmeingyun
# City not found. Skipping
# Processing Record 17 of Set 16 | nanae
# Processing Record 18 of Set 16 | rochegda
# Processing Record 19 of Set 16 | pallasovka
# Processing Record 20 of Set 16 | hihifo
# City not found. Skipping
# Processing Record 21 of Set 16 | belokurikha
# Processing Record 22 of Set 16 | alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0           Dikson      RU  2022-08-08 01:13:56  73.5069   80.5464     42.10
# 1          Rikitea      PF  2022-08-08 01:10:55 -23.1203 -134.9692     72.01
# 2    Prince Rupert      CA  2022-08-08 01:12:04  54.3161 -130.3201     60.96
# 3         Saldanha      ZA  2022-08-08 01:13:57 -33.0117   17.9442     56.89
# 4  Haines Junction      CA  2022-08-08 01:13:58  60.7522 -137.5108     58.82
# 5           Atuona      PF  2022-08-08 01:13:58  -9.8000 -139.0333     77.36
# 6        Cape Town      ZA  2022-08-08 01:13:58 -33.9258   18.4232     56.12
# 7           Lompoc      US  2022-08-08 01:10:51  34.6391 -120.4579     81.01
# 8         Khatanga      RU  2022-08-08 01:13:59  71.9667  102.5000     57.06
# 9       Butaritari      KI  2022-08-08 01:14:00   3.0707  172.7902     81.90
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0       100         100        6.17     overcast clouds
# 1        73         100       34.05          light rain
# 2        69           2        6.85           clear sky
# 3        86          34       12.80    scattered clouds
# 4        47          57        8.88       broken clouds
# 5        67          74       17.20       broken clouds
# 6        90           0        3.00           clear sky
# 7        70           0       25.99           clear sky
# 8        66          41        6.26    scattered clouds
# 9        72          90       14.92     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
